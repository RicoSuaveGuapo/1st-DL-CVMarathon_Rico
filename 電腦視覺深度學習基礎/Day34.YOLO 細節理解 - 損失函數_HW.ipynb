# %% [markdown]
# ## Day34.YOLO 細節理解 - 損失函數
# 今天的課程，我們講述了
# * 損失函數是描述模型預測出來的結果和實際的差異的依據
# * YOLO 損失函數的設計包含物件位置的定位與物件類別辨識
# * YOLO損失函數透過超參數設定模型有不同的辨識能力

# %% [markdown]
# ### 作業
# 仔細觀察，bbox 寬高計算損失方式和bbox中心計算損失方式有哪邊不一樣嗎? 為什麼要有不同的設計?
# ![title](loss function.png)

# %%
'''
bbox 寬高計算損失 是計算寬高開根號後相減在平方
當兩者皆較大時，這種loss會比較小，
換句話說，面積較大時 ground truth 和 predicted 的長寬差比較不重要


bbox 中心計算損失 是兩者差值平方
這種loss不會因為兩者值的大小而改變，這是合理的，因為兩者中心位置不該因為位置不同而計算不同。
'''
